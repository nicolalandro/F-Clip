# %% [markdown]
# # Preparation
# Remember to enable GPU from Runtime>change runtime type
#
# The following block Download code, model and demo img.

# %%
# !git clone https://github.com/nicolalandro/F-Clip.git
# %cd F-Clip

# !wget https://github.com/nicolalandro/F-Clip/releases/download/0.1/HR_checkpoint.pth.tar

# !mkdir demo_input
# !wget -P demo_input https://github.com/mlpc-ucsd/LETR/raw/master/figures/demo.png
# Out:
# Cloning into 'F-Clip'...
# remote: Enumerating objects: 261, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 261 (delta 130), reused 211 (delta 80), pack-reused 0
# Receiving objects: 100% (261/261), 17.04 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (130/130), done.
# /content/F-Clip
# --2022-04-01 10:18:49--  https://github.com/nicolalandro/F-Clip/releases/download/0.1/HR_checkpoint.pth.tar
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # Predict

# %%
# !CUDA_VISIBLE_DEVICES=0 python demo.py \
    ./demo_input --model HR --output_dir demo_result --ckpt ./HR_checkpoint.pth.tar
# Out:
# Namespace(camid=0, ckpt='./HR_checkpoint.pth.tar', display=False, img_glob='*.png', input='./demo_input', model='HR', output_dir='demo_result', skip=1, waitkey=1)
# demo_result
# ==> Loading video.
# [ERROR:0] global /io/opencv/modules/videoio/src/cap.cpp (116) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.1.2) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): ./demo_input in function 'icvExtractPattern'
#
#
# ==> Processing Image Directory Input.
# ==> Successfully loaded video.
# Using device:  cuda
# 0-th head, head type raw, head output 2
# 1-th head, head type raw, head output 2
# 2-th head, head type raw, head output 1
# 3-th head, head type raw, head output 1
# => loading model from ./HR_checkpoint.pth.tar
# Finished constructing model!
# ==> Running Demo.
# ...

# %% [markdown]
# # Show input and prediction

# %%
from PIL import Image

# %%
Image.open('demo_input/demo.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=375x500 at 0x7FEA5FD63990>

# %%
Image.open('demo_result/0001.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=375x500 at 0x7FEA5CCCECD0>
